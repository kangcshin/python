# %%
# !pip install lightfm
# Out:
# Collecting lightfm
#   Downloading lightfm-1.14.tar.gz (250kB)
#     100% |████████████████████████████████| 256kB 2.5MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/dist-packages (from lightfm)
# Requirement already satisfied: requests in /usr/local/lib/python2.7/dist-packages (from lightfm)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python2.7/dist-packages (from lightfm)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests->lightfm)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests->lightfm)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests->lightfm)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests->lightfm)
# Building wheels for collected packages: lightfm
# done
#   Stored in directory: /content/.cache/pip/wheels/15/05/79/ef0517380683841ac13a08cbb8c90f052f954b91b486cc7e68
# Successfully built lightfm
# Installing collected packages: lightfm
# Successfully installed lightfm-1.14

# %%
import numpy as np
from lightfm.datasets import fetch_movielens
from lightfm import LightFM

# %%
data = fetch_movielens(min_rating=4.0)
print(repr(data['train']))
print(repr(data['test']))
# Out:
# <943x1682 sparse matrix of type '<type 'numpy.int32'>'
# 	with 49906 stored elements in COOrdinate format>
# <943x1682 sparse matrix of type '<type 'numpy.int32'>'
# 	with 5469 stored elements in COOrdinate format>

# %%
model = LightFM(loss='warp')

# %%
model.fit(data['train'], epochs=30, num_threads=2)

# %%
def sample_recommendation(model, data, user_ids):
  n_users, n_items = data['train'].shape
  for user_id in user_ids:
    known_positives = data['item_labels'][data['train'].tocsr()[user_id].indices]
    scores = model.predict(user_id, np.arange(n_items))
    top_items = data['item_labels'][np.argsort(-scores)]
    
    print("User %s" % user_id)
    print("     Known positives:")

    for x in known_positives[:3]:
      print("        %s" % x)

      print("     Recommended:")

      for x in top_items[:3]:
        print("        %s" % x)

# %%
sample_recommendation(model, data, [3, 25, 450])
# Out:
# User 3
#      Known positives:
#         Seven (Se7en) (1995)
#      Recommended:
#         Scream (1996)
#         L.A. Confidential (1997)
#         Chasing Amy (1997)
#         Contact (1997)
#      Recommended:
#         Scream (1996)
#         L.A. Confidential (1997)
#         Chasing Amy (1997)
#         Starship Troopers (1997)
#      Recommended:
#         Scream (1996)
#         L.A. Confidential (1997)
#         Chasing Amy (1997)
# User 25
#      Known positives:
#         Dead Man Walking (1995)
#      Recommended:
#         Fargo (1996)
#         Contact (1997)
#         Full Monty, The (1997)
#         Star Wars (1977)
#      Recommended:
#         Fargo (1996)
#         Contact (1997)
#         Full Monty, The (1997)
#         Fargo (1996)
#      Recommended:
#         Fargo (1996)
#         Contact (1997)
#         Full Monty, The (1997)
# User 450
#      Known positives:
#         Contact (1997)
#      Recommended:
#         G.I. Jane (1997)
#         Air Force One (1997)
#         Scream (1996)
#         George of the Jungle (1997)
#      Recommended:
#         G.I. Jane (1997)
#         Air Force One (1997)
#         Scream (1996)
#         Event Horizon (1997)
#      Recommended:
#         G.I. Jane (1997)
#         Air Force One (1997)
#         Scream (1996)
